# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import os
import sys

# %%
No = 1
fig_size = 256
fold = 1

log_path = f"../exp/{fig_size}-{No}/log_No{No}_fold{fold}_{fig_size}.csv"
log_df = pd.read_csv(log_path)
columns = log_df.columns
log_df
# Out:
#    epoch       loss  loss_val  train_acc   val_acc  train_roc   val_roc  \
# 0    0.0  35.598033  8.447131   0.981534  0.982252   0.499650  0.825504
# 1    1.0  31.513300  7.988020   0.982184  0.982252   0.505260  0.815878
# 2    2.0  30.458522  8.213259   0.982069  0.981334   0.502034  0.818356
# 3    3.0  29.870591  8.489183   0.981954  0.981487   0.501975  0.796408
# 4    4.0  27.437986  7.392397   0.982069  0.981640   0.507313  0.872390
# 5    5.0  26.699409  7.158006   0.981916  0.982252   0.511458  0.883582
# 6    6.0  25.539352  7.513498   0.982375  0.982099   0.518027  0.884937
# 7    7.0  24.594484  7.064774   0.982375  0.981181   0.523306  0.889846
# 8    8.0  23.920656  7.747118   0.982451  0.981946   0.540237  0.878263
#
#        lr
# 0  0.0010
# 1  0.0010
# 2  0.0010
# 3  0.0010
# 4  0.0003
# 5  0.0003
# 6  0.0003
# 7  0.0003
# 8  0.0003

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(log_df.loc[:, columns[0]], log_df.loc[:, columns[1]], label=columns[1])
plt.plot(log_df.loc[:, columns[0]], log_df.loc[:, columns[2]], label=columns[2])
plt.legend()
plt.subplot(2, 2, 2)
plt.plot(log_df.loc[:, columns[0]], log_df.loc[:, columns[3]], label=columns[3])
plt.plot(log_df.loc[:, columns[0]], log_df.loc[:, columns[4]], label=columns[4])
plt.legend()
plt.subplot(2, 2, 3)
plt.plot(log_df.loc[:, columns[0]], log_df.loc[:, columns[5]], label=columns[5])
plt.plot(log_df.loc[:, columns[0]], log_df.loc[:, columns[6]], label=columns[6])
plt.legend()
plt.tight_layout()
